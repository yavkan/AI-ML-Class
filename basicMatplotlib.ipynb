# %%
import matplotlib.pyplot as pt

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y= [5, -2, 3, 4, 6, 9, 1]

# %%
pt.plot(x, y)
pt.show()

# %%
pt.scatter(x, y, color="red")
pt.xlabel("X Axis")
pt.ylabel("Y Axis")
pt.title("Graph")
pt.xlim(-10, 20)
pt.ylim(-20, 20)
pt.show()
